# %%
# %matplotlib inline
import matplotlib.pyplot as plt
fig=plt.figure(dpi= 120, facecolor='w', edgecolor='k')
#### read in the txt file
import numpy as np
raw_data = np.loadtxt('../data/pose_data.txt', delimiter=',')

plt.plot(raw_data[5500:10000,1:4])
plt.xlabel("Index")
plt.ylabel("Position (m)")
raw_data.shape

np.savetxt('../data/pose_data_truncated.txt', raw_data[5500:10000,:], fmt="%0.10f", delimiter=', ')
